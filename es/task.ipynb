# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\sssns\\Desktop\\New\\10.09.2025\\E_sim\\Case Study\\Case Study/my_dataset.csv")

# %%
#1	Total number of users and dynamics
df["UserID"].nunique()
# Out:
# 96

# %%
plt.plot(df.groupby("Day")["UserID"].nunique())
